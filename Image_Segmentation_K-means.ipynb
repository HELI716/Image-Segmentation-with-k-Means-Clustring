# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ghost\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ghost\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ghost\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ghost\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ghost\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
image = mpl.image.imread("red_rose.jpg")

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (720, 960, 3)

# %%
X = image.reshape(-1,3)

# %%
X.shape
# Out:
# (691200, 3)

# %%
kmeans = KMeans(n_clusters=2,n_init=10)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, n_init=10)

# %%
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)

# %%
plt.imshow(segmented_img / 255)

# %%
import cv2 
cv2.imwrite("image1.png",cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
cv2.imwrite("image2.png",cv2.cvtColor(segmented_img.astype("uint8"),cv2.COLOR_BGR2RGB))
# Out:
# True
